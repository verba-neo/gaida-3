# %%
import os
from dotenv import load_dotenv
import requests

load_dotenv()
BOT_TOKEN = os.getenv('TELEGRAM_BOT_TOKEN')

TELEGRAM_URI = "https://api.telegram.org/bot"

URL = TELEGRAM_URI + BOT_TOKEN + '/setWebhook' + '?url=https://2914-59-9-164-145.ngrok-free.app/telegram/webhook'     

res = requests.get(URL)

# %%
URL
# Out:
# 'https://api.telegram.org/bot8876236492:AAGCj1MIBb7Ld0vMtwUc1A_MflRbtOxaDaU/setWebhook?url=https://2914-59-9-164-145.ngrok-free.app/telegram/webhook'

# %%
res.json()
# Out:
# {'ok': True, 'result': True, 'description': 'Webhook was set'}
